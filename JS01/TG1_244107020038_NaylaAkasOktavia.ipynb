# %% [markdown]
# <a href="https://colab.research.google.com/github/naylaakas/PembelajaranMesin-2026/blob/main/JS01/TG1_244107020038_NaylaAkasOktavia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BAGIAN 1**

# %%
# !pip install PyPREP
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# !pip install Scipy

# %%
# !pip install wandb

# %%
# !pip install pyECG
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# Jelaskan kegunakan masing-masing library tersebut
#
# 1. PyPREP: Library Python yang digunakan untuk pra-pemrosesan data sinyal otak (EEG).
#
# 2. Scipy: Library mendasar untuk komputasi ilmiah dan matematika dalam Python.
#
# 3. wandb: Platform MLOps yang digunakan untuk melakukan tracking dan visualisasi eksperimen Machine Learning / Deep Learning.
#
# 4. pyECG: Library Python yang dirancang khusus untuk analisis dan pemrosesan sinyal elektrokardiogram (ECG/EKG).

# %% [markdown]
# **BAGIAN 2**
#
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# Etika: Bias Rekrutmen Amazon (2015) — AI memfilter pelamar kerja dan mendiskriminasi kandidat wanita karena dilatih dengan data historis yang didominasi pria. (Ref: https://www.scirp.org/reference/referencespapers?referenceid=3553799)
#
# Hukum: Penggunaan AI generatif untuk membuat video/foto deepfake non-konsensual yang menyebarkan hoaks politik atau konten pornografi tanpa izin pemilik wajah (Ref: https://www.foreignaffairs.com/articles/world/2018-12-11/deepfakes-and-new-disinformation-war)
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
# Dampak: Pelatihan model AI besar boros listrik (memicu emisi karbon tinggi) dan butuh jutaan liter air untuk mendinginkan server.
#
# Solusi: Data center wajib pakai energi terbarukan (surya/angin) dan sistem hemat air. Bikin AI yang lebih efisien (Green AI) agar hemat daya komputasi.
#
# Pendapat: Developer harus mewajibkan audit jejak karbon sebelum merilis model AI baru. (Ref: https://aclanthology.org/P19-1355/)
